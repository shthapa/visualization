# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL ##install as pillow if needed
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots (figsize=(5,3))
ax.plot(x,y1,)
ax.plot(x,y2)

# %%
fig, ab = plt.subplots (figsize=(5,3))
ab.plot(x,y1, label = "Person 1")
ab.plot(x,y2, label = "Person 2")
ab.legend(loc = 'lower right')

# %%
fig, ac = plt.subplots (figsize=(5,3))
ac.plot(x,y1, label = "Person 1")
ac.plot(x,y2, label = "Person 2")
ac.legend(loc = 'lower right',
          frameon = True,
          fontsize = 12,
          shadow = True)
fig.show()
# Out:
# C:\Users\ShaileshT\AppData\Local\Temp\ipykernel_43900\1395912661.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ad = plt.subplots (figsize=(5,3))
ad.plot(x,y1, label = "Person 1")
ad.plot(x,y2, label = "person 2")
ad.legend (loc ='upper left',
           bbox_to_anchor = (1,1))
fig.show()
# Out:
# C:\Users\ShaileshT\AppData\Local\Temp\ipykernel_43900\1453295066.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ae = plt.subplots (figsize=(5,3))
ae.scatter(x,y1, label = "Person 1")
ae.scatter(x,y2, label = "Person 2")
ae.legend(loc = 'lower right')
ae.text(10,95, "This value is important!")
fig.show()
# Out:
# C:\Users\ShaileshT\AppData\Local\Temp\ipykernel_43900\3395212835.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, af = plt.subplots (figsize=(5,3))
af.scatter(x,y1, label = "Person 1")
af.scatter(x,y2, label = "Person 2")
af.legend(loc = 'lower right')
af.text(10,95, "This value is important!",
        ha = 'center',
        color = 'red',
        size =20)
fig.show()
# Out:
# C:\Users\ShaileshT\AppData\Local\Temp\ipykernel_43900\2404900828.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ag = plt.subplots()
ag.axis([0,10,0,10])

ag.text(1,5, ". Data: (1,5)", transform = ag.transData)
ag.text(0.5,0.1, ". Axes:(0.5, 0.1)", transform=ag.transAxes)
ag.text(0.2, 0.22,". Figure:(0.2, 0.2)", transform=fig.transFigure)
# Out:
# Text(0.2, 0.22, '. Figure:(0.2, 0.2)')

# %%
fig, ag = plt.subplots (figsize=(5,3))
ag.scatter(x,y1, label = "Person 1")
ag.scatter(x,y2, label = "Person 2")
ag.legend(loc = 'lower right')

ag.annotate("This is important!", xy = (10,95), xytext = (20,94),
            arrowprops=dict(facecolor='black'))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ag = plt.subplots (figsize=(5,3))
ag.scatter(x,y1, label = "Person 1")
ag.scatter(x,y2, label = "Person 2")
ag.legend(loc = 'lower right')

ag.annotate("This is important!", xy = (10,95), xytext = (20,94),
            arrowprops=dict(facecolor='wedge',
                            color = "hotpink"))
# Out:
# C:\Users\ShaileshT\AppData\Local\Temp\ipykernel_4984\3160354579.py:6: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ag.annotate("This is important!", xy = (10,95), xytext = (20,94),
# Text(20, 94, 'This is important!')

# %%
fig, ag = plt.subplots (figsize=(5,3))
ag.scatter(x,y1, label = "Person 1")
ag.scatter(x,y2, label = "Person 2")
ag.legend(loc = 'lower right')

#ag.yaxis.set_major_locator(plt.NullLocator())
#ag.xaxis.set_major_formatter(plt.NullFormatter())

#ag.xaxis.set_major_locator(plt.MultipleLocator(5))

#ag.xaxis.set_major_locator(plt.MultipleLocator(5))

plt.xticks(rotation=45, ha = 'right', fontsize = 12, font = 'serif')
#plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict= font1)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1)
ax.plot(x,y2)

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp","Sanji"])
y2 = np.array([110,180,240,99,220])

# %%
fig, (ax1, ax2) = plt.subplots(ncols =2,
                               nrows = 1,
                               figsize = (7,3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                   figsize=(7, 4))

someaxes['ax1'].scatter(x1, y1)
someaxes['ax2'].bar(x2, y2)
someaxes['ax3'].plot(x1, y1)

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                   figsize=(7, 4))

someaxes['ax1'].scatter(x1, y1)
someaxes['ax2'].bar(x2, y2)
someaxes['ax3'].plot(x1, y1)

someaxes['ax1'].set_xlabel('A Big Label', fontsize=18)
someaxes['ax2'].set_xlabel('Another Label', fontsize=18)
someaxes['ax3'].set_xlabel('Label 2: 2 Fast 2 Furious', fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
x = np.array(['Luffy', 'Zoro', 'Nami','Usopp','Sanji'])
y1= np.array ([110,180,240,99,220])
y2 = np.array ([170,100,90,120,50])

fig, ax = plt.subplots(figsize=(7,3))
ax.bar(x,y1, color = 'indigo')
ax.plot(x,y2, color = 'red')

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize = (7,3))
ax.plot (x,y2, color = 'red')

ax.errorbar(x,y2,
            yerr= y2_sd,
            fmt = 'none',
            ecolor = 'indigo',
            elinewidth = 4,
            capsize = 6,
            capthick =4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png', verify=False)
image_file = BytesIO(response.content)
image = Image.open(image_file)


x = [1, 2, 3, 4, 5]
y2 = [2, 3, 5, 7, 11]


fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color='red')


ax_image = fig.add_axes([0.1, 0.11, 0.15, 0.35]) 
ax_image.imshow(image)
ax_image.axis('off')
# Out:
# c:\Users\ShaileshT\AppData\Local\miniconda3\envs\dsi_participant\lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'upload.wikimedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# (-0.5, 219.5, 425.5, -0.5)
